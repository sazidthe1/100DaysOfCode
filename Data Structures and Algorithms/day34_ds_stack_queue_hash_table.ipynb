# %% [markdown]
# ## Day 34 of 100DaysOfCode 🐍
# ### Data Structure (DS) - Stack, Queue, Hash Table

# %% [markdown]
# ### **Data Structure - Stack 📚🔄**
#
# Stack is a linear data structure that follows a particular order in which the operations are performed. The order may be **LIFO** (Last In First Out) or **FILO** (First In Last Out). LIFO implies that the element that is inserted last, comes out first and FILO implies that the element that is inserted first, comes out last.
#
# > Example: Plates stacked over one another in the canteen. The plate which is at the top is the first one to be removed, i.e. the plate which has been placed at the bottommost position remains in the stack for the longest period of time.

# %% [markdown]
# ![stack.png](data:image/png;base64,...)

# %% [markdown]
# ### **Data Structure - Queue 🚶‍♂️🚶**
#
# A Queue is defined as a linear data structure that is open at both ends and the operations are performed in **FIFO** (First In First Out) order.
#
# > Example: A Queue is like a line waiting to purchase tickets, where the first person in line is the first person served. (i.e. First come first serve).
#
# #### **Characteristics of Queue**
# - Can handle multiple data
# - Can be accessed from both ends
# - Fast and flexible.

# %% [markdown]
# ![queue.png](data:image/png;base64,...)

# %% [markdown]
# ### **Data Structure - Hash Table 🗄️🔑**
#
# Hash Table is a data structure which stores data in an associative manner. In a hash table, data is stored in an array format, where each data value has its own unique index value. Access of data becomes very fast if we know the index of the desired data.
#
# <br>
#
# #### **Hashing**
#
# Hashing is a technique or process of mapping keys, and values into the hash table by using a hash function. It is done for faster access to elements. The efficiency of mapping depends on the efficiency of the hash function used.
# > Let a hash function H(x) maps the value x at the index x%10 in an Array. For example if the list of values is [11,12,13,14,15] it will be stored at positions {1,2,3,4,5} in the array or Hash table respectively.

# %% [markdown]
# ![hashing.png](data:image/png;base64,...)

# %% [markdown]
# © **Courtesy** [GeeksforGeeks](https://www.geeksforgeeks.org/data-structures) 🙏
