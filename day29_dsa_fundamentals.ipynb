# %% [markdown]
# ## Day 29 of 100DaysOfCode 🐍
# ### Data Structures and Algorithms (DSA) - Fundamentals, Big O notation

# %% [markdown]
# ### **Data Structures and Algorithms (DSA) 🗂️🔢**
# Data Structures and Algorithms (DSA) refer to the fundamental concepts and techniques used to organize, store, manipulate, and analyze data efficiently.

# %% [markdown]
# ### **DSA in the Context of Data Science 📊🔍🔢**
#
# Learning DSA is crucial for data scientists due to the following reasons: 🎯🔬
#
# 1. **Efficient Data Processing:** DSA helps data scientists select and implement appropriate data structures and algorithms to efficiently process and analyze large volumes of data. This enables faster and more efficient computations, leading to improved data processing workflows. ⚡💻
#
# 2. **Optimization of Algorithms:** Understanding and implementing efficient algorithms is essential for optimizing the performance of data science tasks. DSA provides techniques for analyzing algorithm efficiency, such as time and space complexity analysis, allowing data scientists to design algorithms that are both accurate and efficient. 📈📉
#
# 3. **Handling Complex Data Structures:** Many real-world datasets require complex data structures to represent and store information effectively. DSA equips data scientists with the knowledge and skills to work with these data structures, enabling them to handle diverse types of data efficiently. 🏗️📂
#
# 4. **Algorithm Design for Machine Learning:** DSA plays a significant role in designing and implementing various machine learning algorithms. Concepts such as sorting, searching, and graph traversal algorithms are foundational for developing robust and accurate machine learning models. 🤖📚

# %% [markdown]
# ### **Applications of DSA in Data Science 📊🔍🔢**
#
# DSA has wide-ranging applications in the field of data science, including: 📊🔬🚀
#
# - **Data Cleaning and Preprocessing:** DSA techniques are used to preprocess and clean datasets, such as removing outliers, handling missing values, and transforming data into suitable formats for analysis. 🧹🔍💡
#
# - **Feature Engineering:** DSA helps data scientists create and manipulate features, such as transforming categorical variables, scaling numerical features, and creating new features based on domain knowledge. 🛠️🔧✨
#
# - **Optimization and Hyperparameter Tuning:** DSA provides algorithms and techniques for optimizing model parameters and hyperparameters, enabling data scientists to fine-tune machine learning models for improved performance. 📈🎛️
#
# - **Graph Analysis:** DSA is essential for analyzing and extracting insights from graph-structured data, such as social networks, recommendation systems, and network analysis. 🌐📊🕸️
#
# - **Natural Language Processing (NLP):** DSA techniques are employed in various NLP tasks, such as text tokenization, sentiment analysis, named entity recognition, and topic modeling. 🗣️📖📊
#
# - **Image Processing and Computer Vision:** DSA algorithms are used in image processing and computer vision tasks, including image segmentation, object detection, and image classification. 🖼️👁️🔍
#
# By learning DSA in Python, data scientists gain a strong foundation in efficient data processing, algorithm design, and data structure implementation, enabling them to tackle complex data science problems effectively. 💪🔬🚀

# %% [markdown]
# ### **Big O notation 📈**
#
# Big O notation is a mathematical notation used in computer science to describe the performance or complexity of an algorithm. It represents the upper bound or worst-case scenario of the time or space complexity of an algorithm as the input size increases.

# %% [markdown]
# ### **Purpose of Big O notation ✨**
#
# The purpose of Big O notation is to provide a standardized way of analyzing and comparing the efficiency of algorithms. It allows us to understand how an algorithm's performance scales with larger input sizes and helps us make informed decisions when selecting algorithms for solving specific problems.

# %% [markdown]
# ### **Advantages of Big O notation ✅**
#
# 🔹 **Standardized Comparison**: Big O notation provides a common language for expressing the efficiency of algorithms, allowing for easy comparison and evaluation of different approaches.
#
# 🔹 **Algorithm Selection**: Big O notation helps in selecting the most efficient algorithm for a specific problem by considering its time and space complexity.
#
# 🔹 **Efficiency Analysis**: Big O notation helps in analyzing the efficiency of an algorithm by providing insights into its growth rate as the input size increases.
#
# 🔹 **Scalability Prediction**: Big O notation allows us to predict the performance of an algorithm for larger input sizes without actually running the code.
#
# 🔹 **Communication and Collaboration**: Big O notation serves as a universal language for discussing and communicating algorithmic complexity among developers, researchers, and professionals in the field of computer science.
#
# By leveraging Big O notation, we can analyze, compare, and select algorithms based on their efficiency. It helps in understanding the scalability and performance limitations of algorithms, aiding in the design and optimization of software systems.

# %% [markdown]
# #### **Traditional Approach**

# %%
import time

# Start the timer
start_time = time.time()

empty_list = []

for i in range(10000000):
  empty_list.append(i)

# End the timer
end_time = time.time()

# Calculate the execution time
execution_time = end_time - start_time

# Print the execution time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 1.3372271060943604 seconds

# %% [markdown]
# #### **Courtesy ©️ [Codebasics](https://youtu.be/IR_S8BC8KI0) 🙏**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Bio O notation Applications - Time Complexity**
#
# Rules:
# *   Keep fastest growing term
# *   Drop constants

# %% [markdown]
# ##### **Here, time = a * n² + b → O(n²)**

# %%
numbers = [3,5,2,7,4,3,6,7,8,9]

for i in range(len(numbers)):
  for j in range(i+1, len(numbers)):
    if numbers[i] == numbers[j]:
      print(str(numbers[i]) + " is a duplicate value!")
      break
# Out:
# 3 is a duplicate value!
# 7 is a duplicate value!

# %% [markdown]
# ##### **Here, time = a * n² + b * n + c → O(n²)**

# %%
numbers = [3,5,2,7,4,3,6,7,8,9]
duplicates = []

for i in range(len(numbers)):             # n² iterations
  for j in range(i+1, len(numbers)):
    if numbers[i] == numbers[j]:
      duplicates = numbers[i]
      break

for i in range(len(numbers)):             # n iterations
  if numbers[i] == duplicates:
    print(str(i) + " is a duplicate value!")
# Out:
# 3 is a duplicate value!
# 7 is a duplicate value!

# %% [markdown]
# #### **Bio O notation Applications - Space Complexity**
#
# Rules:
# *   Keep fastest growing term
# *   Drop constants

# %% [markdown]
# ##### **Here, time = a * n² + b * n + c → O(n²)**

# %% [markdown]
# ##### **Search for 68**
#
# `|4|9|15|21|34|57|68|91|`
#
# `|4|9|15|21|34|57|68|91|`     Iteration 1 = n/2
#
# `|34|57|68|91|`    Iteration 2 = (n/2)/2 = n/2²
#
# `|68|91|`    Iteration 3 = (n/2²)/2 = n/2³
#
# ________________________________________________
#
# ![Screenshot 2023-07-19 at 10.10.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-07-19 at 10.12.50 PM.png](data:image/png;base64,...)
