# %% [markdown]
# ## Day 41 of 100DaysOfCode 🐍
# ### Web Scraping - HTTP Request, Request Headers, Response, JSON, API

# %% [markdown]
# ### **Web Scraping 🕸️🕷️**
#
# Web scraping is the automated process of extracting data from websites.
#
# It can be also said as..
#
# - Web data extraction, web crawling
# - Structuring data from the web
# - Automation
# - Retrieve hundreds data

# %% [markdown]
# #### **Use Cases of Web Scraping 🔍🗃️**
#
# - Monitoring e-commerce prices
# - Finding opportunities for the investment
# - Analyzing social media web data
# - Applying ML techniques
# - Gathering web data automatically
# - Researching new concepts in a field
# - Extracting  control info
# - Monitoring news sources
# - Generating Sales leads
# - Kaggle

# %% [markdown]
# #### **Ethics of Scraping 🤔🕸️**
#
# - Do not engage in privacy or unauthorized commercial use of extracted data
# - Read the robots.txt of the site
# - Do not spam

# %% [markdown]
# #### **HTTP Requests 🌐📥**
#
# - On the web, servers and clients usually communicate through HTTP request
# - The two most popular requests types are **GET** and **POST**
# <br>
#
# **GET**
# - Obtain data from server
# - Can be bookmarked
# - Parameter are added directly into the url
# - Not used to send sensitive info (such as password)
# <br>
#
# **POST**
# - Obtain data from server
# - Can’t be bookmarked
# - Parameter are added directly into the url
# - Not used to send sensitive info (such as password)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# #### **Request Headers 🌐🎯**
#
# - A request header is an HTTP header that can be used in an HTTP request to provide info about the request context, so that the server can tailor the response.
# - The two most common headers fields are the **User-Agent** and **Cookies**

# %% [markdown]
# #### **User-Agent 🕵️‍♂️📱**
#
# - A relatively short bit of text
# - Describe the software/browser that is making the  request to the website
# - The user agent if often include description of the Operating System and Device type

# %% [markdown]
# #### **Cookies 🍪**
#
# - Text files with small pieces of data -  like username and password
# - Specific cookies known as HTTP cookies are used to identify specific users and improve your web browsing experience

# %% [markdown]
# #### **Response 📬**
#
# A response is received from the web server.
#
# The response contains 2 main pieces of info:
# - The response headers
# - The status code
#
# <br>
#
# Every response will have a status code.
# - Informational responses (100–199)
# - Successful responses (200–299)
# - Redirects (300–399)
# - Client errors (400–499)
# - Server errors (500–599)

# %% [markdown]
# ![request & response.png](data:image/png;base64,...)

# %% [markdown]
# #### **JSON 🧱🔤**
#
# JSON stands for _JavaScript Object Notation_. It is a text based format for storing and transporting data between computers.
#
# <br>
#
# JSON is building upon 2 data structures in Python.
# - Dictionary
# - List

# %% [markdown]
# #### **API 🔌**
#
# API stands for _Application Programming Interface_. An API is a way for two or more computer programs to communicate with each other. Usally contacts between client and server.
# <br>
#
# - It can extend the functionality of the browser
# - It can greatly simplify complex functions
# - It can provide easy syntax to complex code

# %% [markdown]
# ![Picture4.png](data:image/png;base64,...)
